# %% [markdown]
#  En la línea 15 encontramos la variable PI = 3.14159
#  Al ser el número PI una constante matemática, ha de ser escrita con mayúsculas, por lo que hasta aquí el código está correcto. Ponerle NUM delante no sería válido porque NUM es un cuantificador.

# %%
PI = 3.14159
print(PI)
# Out:
# 3.14159

# %% [markdown]
#  En la segunda líne la variable g se refiere a una lista que guarda 5 números de diez en diez, g no es un nombre adecuado para una variable en python según las convenciones, un ejemplo de nombre apropiado sería: LISTA_DIEZ_EN_DIEZ

# %%
LISTA_DIEZ_EN_DIEZ = [10, 20, 30, 40, 50]
print(LISTA_DIEZ_EN_DIEZ)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
#  temp = media
#  z= maximo
#  w = minimo

# %% [markdown]
#  Es un enumerado (RED, GREEN, BLUE)

# %%
Enum Color
    Color_Red
    Color_Green
    Color_Blue
End Enum
# Out:
#   Cell In[3], line 1
#     Enum Color
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
#  Las flag: si flag = True, se cumplirán ciertas cosas . Se nombran con is.

# %% [markdown]
#  i se utiliza para encontrar ciertas posiciones

# %% [markdown]
#  len(g), mide la longuitud de la lista, en este caso es igual a 5. len() también funciona con strings.

# %% [markdown]
#  range(len(g)), devuelve 5 valores (por la longuitud) que van a ser del 0 al 4
